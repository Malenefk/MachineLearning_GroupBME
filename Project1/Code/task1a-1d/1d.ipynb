# %% [markdown]
# # Task 1D

# %%
import numpy as np
np.random.seed(3155)
n = 500
x = np.linspace(-1,1, n) #x within interval [-1,1]
denominator = 1+(25*x**2)
y = 1/denominator+ np.random.normal(0, 1, x.shape)

# %%
from functions import gradient_momentum, polynomial_features, OLS_parameters, Ridge_parameters, gradient_momentum, gradient_adagrad, gradient_rmsprop, gradient_adam, all_learning_rates_plot

# %%
all_learning_rates_plot(x,y)
# Out:
# loop broken at 319 for degree: 1
# loop broken at 287 for degree: 2
# loop broken at 311 for degree: 3
# loop broken at 299 for degree: 4
# loop broken at 310 for degree: 5
# loop broken at 314 for degree: 6
# loop broken at 291 for degree: 7
# loop broken at 308 for degree: 8
# loop broken at 301 for degree: 9
# loop broken at 300 for degree: 10
# loop broken at 296 for degree: 11
# loop broken at 308 for degree: 12
# loop broken at 308 for degree: 13
# loop broken at 308 for degree: 14
# loop broken at 291 for degree: 15
# loop broken at 300 for degree: 16
