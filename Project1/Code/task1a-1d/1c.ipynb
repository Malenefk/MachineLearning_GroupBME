# %% [markdown]
# # Task 1C

# %%
from functions import polynomial_features, OLS_parameters, Ridge_parameters, gradient, dataset_runge

# %%
import numpy as np
np.random.seed(3155)

# %%
n = 500
x = np.linspace(-1,1, n) #x within interval [-1,1]
denominator = 1+(25*x**2)
y = 1/denominator+ np.random.normal(0, 1, x.shape)

# %%
gradient(x, y, 16)
