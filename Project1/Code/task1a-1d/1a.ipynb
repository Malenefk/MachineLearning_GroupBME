# %% [markdown]
# # Task 1A

# %%
from functions import polynomial_features, OLS_parameters, mse_poly_plot_OLS
import numpy as np 
np.random.seed(3155)

# %%
OLS = mse_poly_plot_OLS(degree=15, intercept=False)
