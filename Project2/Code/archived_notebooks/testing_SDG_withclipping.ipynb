# %%
import neuralnetwork
from neuralnetwork import FFNN 
from neuralnetwork import Sigmoid
from neuralnetwork import MSE
from neuralnetwork import Adam
from neuralnetwork import Activations
from neuralnetwork import Constant
from neuralnetwork import RMS_prop
import math
import autograd.numpy as np
import sys
import warnings
from autograd import grad, elementwise_grad
from random import random, seed
from copy import deepcopy, copy
from typing import Tuple, Callable
from sklearn.utils import resample

# %% [markdown]
# # introducing gradient clipping
# - read that notebook to understand the different approaches

# %%
#Setting up the input to use on the neural network script imported, using Runges Function

#Importing packages
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler

#Random seed to keep the results consistent 
np.random.seed(2030)

def Runge():
    n = 500
    x = np.linspace(-1,1,n).reshape(-1,1) #interval between -1 and 1 formatted to fit in shape with the neural network
    denominator = 1 + (25*x**2) 
    y = 1 / denominator #will not add noise right now
    return x, y  

x, y = Runge()

#Setting up the design matrix is not necessary since we are using the neural network 
#But we still need to do some scaling
Xtrain, Xtest, ytrain, ytest = train_test_split(x,y, test_size=0.2, random_state=42)
#Scale data 
Scaling = StandardScaler(with_std = True)
Scaling.fit(Xtrain)
Xtrain = Scaling.transform(Xtrain)
Xtest = Scaling.transform(Xtest)

ymin, ymax = ytrain.min(), ytrain.max()
ytrain = (ytrain - ymin) / (ymax - ymin)
ytest = (ytest - ymin) / (ymax - ymin)

# %%
if __name__ == '__main__':
    
    b_1h_50n = FFNN(
        nodes = (1,50,1),
        hidden_activation=Sigmoid(),
        output_activation = lambda x: x, 
        cost_func = MSE()
    )

    results = b_1h_50n.fit(
        X = Xtrain, 
        t = ytrain,
        scheduler = Adam(eta = 0.01, rho=0.9, rho2=0.99),
        batches = 4,
        epochs = 300,
        lam = 0.01
    )
# Out:
# Adam: Eta=0.01, Lambda=0.01
#   [=======================================>] 100.0% | train_error: 0.0609

# %%
 if __name__ == '__main__':
    
    b_2h_50_100n = FFNN(
        nodes = (1,50,100,1),
        hidden_activation=Sigmoid(),
        output_activation = lambda x: x, 
        cost_func = MSE()
    )

    results = b_2h_50_100n.fit(
        X = Xtrain, 
        t = ytrain,
        scheduler = Adam(eta = 0.01, rho=0.9, rho2=0.99),
        batches = 4,
        epochs = 300,
        lam = 0.01
    )
# Out:
# Adam: Eta=0.01, Lambda=0.01
#   [=======================================>] 100.0% | train_error: 0.116

# %%
 if __name__ == '__main__':
    
    b_2h_50_100n_ADAMupdated = FFNN(
        nodes = (1,50,100,1),
        hidden_activation=Sigmoid(),
        output_activation = lambda x: x, 
        cost_func = MSE()
    )

    results = b_2h_50_100n_ADAMupdated.fit(
        X = Xtrain, 
        t = ytrain,
        scheduler = Adam(eta = 0.001, rho=0.9, rho2=0.99),
        batches = 4,
        epochs = 300,
        lam = 0.01
    )
# Out:
# Adam: Eta=0.001, Lambda=0.01
#   [=======================================>] 100.0% | train_error: 0.0899

# %%
#this one is new  
if __name__ == '__main__':
    
    b_2h_50_ADAMupdated = FFNN(
        nodes = (1,50,1),
        hidden_activation=Sigmoid(),
        output_activation = lambda x: x, 
        cost_func = MSE()
    )

    results = b_2h_50_ADAMupdated.fit(
        X = Xtrain, 
        t = ytrain,
        scheduler = Adam(eta = 0.001, rho=0.9, rho2=0.99),
        batches = 4,
        epochs = 300,
        lam = 0.01
    )
# Out:
# Adam: Eta=0.001, Lambda=0.01
#   [=======================================>] 100.0% | train_error: 0.0545

# %%
# up 

if __name__ == '__main__':
    
    b_2h_50_100n_SGD = FFNN(
        nodes = (1,50,100,1),
        hidden_activation=Sigmoid(),
        output_activation = lambda x: x, 
        cost_func = MSE()
    )

    results = b_2h_50_100n_SGD.fit(
        X = Xtrain, 
        t = ytrain,
        scheduler = Constant(eta = 0.01),
        batches = 4,
        epochs = 300,
        lam = 0.01
    )
# Out:
# Constant: Eta=0.01, Lambda=0.01
#   [=======================================>] 100.0% | train_error: 0.0333

# %%
 if __name__ == '__main__':
    
    b_1h_50n_SGD = FFNN(
        nodes = (1,50,1),
        hidden_activation=Sigmoid(),
        output_activation = lambda x: x, 
        cost_func = MSE()
    )

    results = b_1h_50n_SGD.fit(
        X = Xtrain, 
        t = ytrain,
        scheduler = Constant(eta = 0.01),
        batches = 4,
        epochs = 300,
        lam = 0.01
    )
# Out:
# Constant: Eta=0.01, Lambda=0.01
#   [=======================================>] 100.0% | train_error: 0.0513

# %%
 if __name__ == '__main__':
    
    b_1h_50n_SGD = FFNN(
        nodes = (1,50,1),
        hidden_activation=Sigmoid(),
        output_activation = lambda x: x, 
        cost_func = MSE()
    )

    results = b_1h_50n_SGD.fit(
        X = Xtrain, 
        t = ytrain,
        scheduler = Constant(eta = 0.0080),
        batches = 4,
        epochs = 300,
        lam = 0.01
    )
# Out:
# Constant: Eta=0.008, Lambda=0.01
#   [=======================================>] 100.0% | train_error: 0.0532

# %%
 if __name__ == '__main__':
    
    b_2h_50n_100_n_SGD = FFNN(
        nodes = (1,50,100,1),
        hidden_activation=Sigmoid(),
        output_activation = lambda x: x, 
        cost_func = MSE()
    )

    results = b_2h_50n_100_n_SGD.fit(
        X = Xtrain, 
        t = ytrain,
        scheduler = Constant(eta = 0.00006),
        batches = 4,
        epochs = 300,
        lam = 0.01
    )
# Out:
# Constant: Eta=6e-05, Lambda=0.01
#   [=======================================>] 100.0% | train_error: 0.0714

# %%
 if __name__ == '__main__':
    
    b_2h_50n_100n_SGD_1000e = FFNN(
        nodes = (1,50,100,1),
        hidden_activation=Sigmoid(),
        output_activation = lambda x: x, 
        cost_func = MSE()
    )

    results = b_2h_50n_100n_SGD_1000e.fit(
        X = Xtrain, 
        t = ytrain,
        scheduler = Constant(eta = 0.00006),
        batches = 4,
        epochs = 100,
        lam = 0.01
    )
# Out:
# Constant: Eta=6e-05, Lambda=0.01
#   [=======================================>] 100.0% | train_error: 0.0976

# %%
 if __name__ == '__main__':
    
    b_2h_50n_100n_SGD_100e_50b = FFNN(
        nodes = (1,50,100,1),
        hidden_activation=Sigmoid(),
        output_activation = lambda x: x, 
        cost_func = MSE()
    )

    results = b_2h_50n_100n_SGD_100e_50b.fit(
        X = Xtrain, 
        t = ytrain,
        scheduler = Constant(eta = 0.00006),
        batches = 10,
        epochs = 100,
        lam = 0.01
    )
# Out:
# Constant: Eta=6e-05, Lambda=0.01
#   [=======================================>] 100.0% | train_error: 0.0766

# %%
 if __name__ == '__main__':
    
    b_1h_50n_SGD_100e_50b = FFNN(
        nodes = (1,50,1),
        hidden_activation=Sigmoid(),
        output_activation = lambda x: x, 
        cost_func = MSE()
    )

    results = b_1h_50n_SGD_100e_50b.fit(
        X = Xtrain, 
        t = ytrain,
        scheduler = Constant(eta = 0.00006),
        batches = 50,
        epochs = 150,
        lam = 0.01
    )
# Out:
# Constant: Eta=6e-05, Lambda=0.01
#   [=======================================>] 100.0% | train_error: 0.736

# %%
 if __name__ == '__main__':
    
    b_1h_50n_SGD_100e_50b_RMS = FFNN(
        nodes = (1,50,1),
        hidden_activation=Sigmoid(),
        output_activation = lambda x: x, 
        cost_func = MSE()
    )

    results = b_1h_50n_SGD_100e_50b_RMS.fit(
        X = Xtrain, 
        t = ytrain,
        scheduler = RMS_prop(eta = 0.00006, rho = 0.9),
        batches = 50,
        epochs = 150,
        lam = 0.01
    )
# Out:
# RMS_prop: Eta=6e-05, Lambda=0.01
#   [=======================================>] 100.0% | train_error: 0.0485

# %%
 if __name__ == '__main__':
    
    b_1h_50n_SGD_100e_10b_RMS = FFNN(
        nodes = (1,50,1),
        hidden_activation=Sigmoid(),
        output_activation = lambda x: x, 
        cost_func = MSE()
    )

    results = b_1h_50n_SGD_100e_10b_RMS.fit(
        X = Xtrain, 
        t = ytrain,
        scheduler = RMS_prop(eta = 0.00006, rho = 0.9),
        batches = 10,
        epochs = 150,
        lam = 0.01
    )
# Out:
# RMS_prop: Eta=6e-05, Lambda=0.01
#   [=======================================>] 100.0% | train_error: 0.0758

# %%
 if __name__ == '__main__':
    
    b_1h_50n_SGD_500e_10b_RMS = FFNN(
        nodes = (1,50,1),
        hidden_activation=Sigmoid(),
        output_activation = lambda x: x, 
        cost_func = MSE()
    )

    results = b_1h_50n_SGD_500e_10b_RMS.fit(
        X = Xtrain, 
        t = ytrain,
        scheduler = RMS_prop(eta = 0.00006, rho = 0.9),
        batches = 10,
        epochs = 500,
        lam = 0.01
    )
# Out:
# RMS_prop: Eta=6e-05, Lambda=0.01
#   [=======================================>] 100.0% | train_error: 0.0453

# %%
 if __name__ == '__main__':
    
    b_1h_50n_SGD_500e_10b_RMS_b = FFNN(
        nodes = (1,50,1),
        hidden_activation=Sigmoid(),
        output_activation = lambda x: x, 
        cost_func = MSE()
    )

    results = b_1h_50n_SGD_500e_10b_RMS_b.fit(
        X = Xtrain, 
        t = ytrain,
        scheduler = RMS_prop(eta = 0.0005, rho = 0.9),
        batches = 10,
        epochs = 150,
        lam = 0.01
    )
# Out:
# RMS_prop: Eta=0.0005, Lambda=0.01
#   [=======================================>] 100.0% | train_error: 0.0468
